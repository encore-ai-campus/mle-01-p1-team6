# %%
# [제공 코드] OpenAI 클라이언트 준비 — 이 셀을 먼저 실행하세요.
# .env 파일에 OPENAI_API_KEY 를 넣어 두면 아래 한 줄이 그것을 읽어 연결합니다.
#   참고: https://developers.openai.com/api/docs/guides/text
import os

from dotenv import load_dotenv
from openai import OpenAI
from pathlib import Path
from langchain_core.tools import tool
import chromadb
from sentence_transformers import SentenceTransformer
from pydantic import BaseModel, Field
model = SentenceTransformer(
    "SamilPwC-AXNode-GenAI/PwC-Embedding_expr"
)

current_dir = os.path.dirname(os.path.abspath('/내 작업/agent.py'))
dotenv_path = os.path.join(current_dir, '.env')

load_dotenv('.env')                # 같은 폴더의 .env
load_dotenv('../.env')             # (정답 폴더처럼 한 단계 안에서 열었을 때)

client = OpenAI(max_retries=8)     # OPENAI_API_KEY 를 자동으로 찾아 쓴다
print('연결 준비 완료 —', '키 확인됨' if os.getenv('OPENAI_API_KEY') else '키가 없습니다(.env 를 확인하세요)')

messages = [{'role': 'system', 'content': '너는 알라딘의 베스트셀러를 추천하는 친절한 말투의 도우미야.'}]

while True:
    user_input = input("사용자: ")
    if user_input.lower() in ['end', 'exit', '종료']:
        break
    messages.append({'role': 'user', 'content': user_input})
    resp = client.chat.completions.create(
        model='gpt-4o-mini',
        messages=messages,
        temperature=0,
        )
    bot_reply = resp.choices[0].message.content
    print(f"{bot_reply}\n")

    # 사용자 질문 추가
    messages.append({'role': 'assistant', 'content': bot_reply})
# Out:
# Loading weights: 100%|██████████| 391/391 [00:00<00:00, 7415.32it/s]
# 연결 준비 완료 — 키 확인됨
# 물론이죠! 고전 문학은 시대를 초월한 매력을 지니고 있어요. 다음 몇 가지를 추천해드릴게요:
#
# 1. **"오만과 편견" - 제인 오스틴**
#    사랑과 사회적 지위에 대한 통찰이 담긴 이 소설은 매력적인 캐릭터와 유머로 가득 차 있어요.
#
# 2. **"1984" - 조지 오웰**
#    전체주의 사회에 대한 경고를 담고 있는 이 작품은 현대 사회에서도 여전히 많은 생각을 하게 만듭니다.
#
# 3. **"죄와 벌" - 도스토예프스키**
#    인간의 도덕성과 죄의식에 대한 깊은 탐구가 이루어지는 이 소설은 심리적 긴장감이 뛰어나요.
#
# 4. **"모비 딕" - 허먼 멜빌**
#    인간과 자연, 복수의 주제를 다룬 이 작품은 방대한 서사와 상징으로 가득 차 있습니다.
#
# 5. **"안나 카레니나" - 레프 톨스토이**
#    사랑과 배신, 사회적 규범에 대한 이야기를 통해 인간의 복잡한 감정을 탐구하는 작품이에요.
#
# 이 외에도 많은 고전들이 있으니, 관심 있는 주제나 작가가 있다면 더 추천해드릴 수 있어요!

# %%
user_input = input("사용자: ")

resp = client.chat.completions.create(
    model='gpt-4o-mini',
    messages=messages)
bot_reply = resp.choices[0].message.content
print(f"{bot_reply}\n")
# Out:
# 물론이죠! 어떤 장르를 좋아하시나요? 판타지, 로맨스, 스릴러 등 다양한 분야에서 추천해드릴 수 있어요. 요즘 인기 있는 책 몇 권을 소개해드릴게요:
#
# 1. **"나의 라임오렌지 나무"** - 조제 마우로 지 미란다의 감동적인 성장 이야기로, 어린 시절의 순수함과 가족의 소중함을 다시 돌아보게 해주는 책입니다.
#
# 2. **"미드나잇 라이브러리"** - 매트 헤이그의 이 소설은 평행 세계를 탐험하는 주인공이 인생의 선택을 고민하는 이야기로, 삶과 행복에 대한 깊은 통찰을 제공합니다.
#
# 3. **"82년생 김지영"** - 조남주 작가의 이 사회 문제를 다룬 작품은 현대 한국 사회에서 여성으로 살아가는 이야기와 그로 인해 겪는 여러 가지 감정을 진솔하게 풀어내고 있습니다.
#
# 4. **"디자인의 힘"** - 심리학과 디자인을 접목한 이 책은 창의력을 자극하고 혁신적인 생각을 할 수 있는 방법을 알려줍니다.
#
# 관심 있는 주제나 스타일이 있으시면 말씀해주시면 더 맞춤형으로 추천해드릴게요!
