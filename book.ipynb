# %% [markdown]
# # 출처 문구 : 도서 DB 제공 : 알라딘 인터넷서점(www.aladin.co.kr)

# %%
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# all_bestsellers.json: 상품 정보 + 리뷰 목록
# all_bestsellers.csv: 리뷰 목록이 JSON 문자열로 포함
# all_community_reviews.json/csv: 리뷰만 한 행씩 별도 저장

# %%
df=pd.read_csv('./output/all_filled.csv')
# df=df.drop(columns=['reviewList','communityReviews','publisherDescription','bestSellerRank'])
df.columns
# Out:
# Index(['category_name', 'category_id', 'rank_in_category', 'itemId', 'title',
#        'author', 'publisher', 'pubDate', 'isbn', 'isbn13', 'priceSales',
#        'priceStandard', 'salesPoint', 'customerReviewRank', 'link', 'cover',
#        'description', 'fullDescription'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# category_name          0
# category_id            0
# rank_in_category       0
# itemId                 0
# title                  0
# author                 0
# publisher              0
# pubDate                0
# isbn                   0
# isbn13                 2
# priceSales             0
# priceStandard          0
# salesPoint             0
# customerReviewRank     0
# link                   0
# cover                  0
# description           85
# fullDescription       41
# dtype: int64

# %%
df1=pd.read_csv('./output/all_community_reviews.csv')
df1['content']
# Out:
# 0                          마지막 책이 되었네요.\r\n삼가 고인의 명복을 빕니다.
# 1        아이고 작가님 왜 이리 일찍 가셨어요ㅠㅠ\r\n갈릴레오 마지막 시리즈일거라고 상상도...
# 2        작가님.ㅠㅠ 책 어제 받았는데 이게 무슨 소식인가요..\r\n정말 감사했습니다. 늘...
# 3        스마트폰 처 박아 놓을 정도로 재밌게 읽었습니다. 작가님의 *비밀*로 시작해서 *투...
# 4                 잘가시오 영원한 친구여 영원한 스승이요 영원원 작가요\r\n그리울것시외다
#                                ...
# 42272    인공지능의 출현은 이제까지와는 차원을 달리한 새로운 세계가 열린 것이고 새로운 몸을...
# 42273    『CISO의 시선으로 바라본 정보보안 실무』 도서 리뷰\r\n˝기술을 넘어 사람과 ...
# 42274                 수업과 업무에 활용할 수 있는 다양한 숨겨진 기능들 기대됩니다^^
# 42275    *이 글을 출판사로부터 도서를 제공받아 작성한 체험단 글입니다.\r\n컴퓨터 기능들...
# 42276               요즘 공무원 사회에서도 인공지능 활용은 반드시 필요하죠. 기대됩니다.
# Name: content, Length: 42277, dtype: object
